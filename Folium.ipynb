# %%
# !pip install pandas==1.3.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 84.6 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# ...

# %%
# !pip3 install folium==0.5.0
import folium

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
# Download and read the `spacex_launch_geo.csv`
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
spacex_df=pd.read_csv(URL)

# %%
spacex_df
# Out:
#     Flight Number        Date Time (UTC) Booster Version   Launch Site  \
# 0               1  2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1               2  2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2               3  2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3               4  2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4               5  2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# 5               7  2013-12-03   22:41:00         F9 v1.1   CCAFS LC-40
# 6               8  2014-01-06   22:06:00         F9 v1.1   CCAFS LC-40
# 7               9  2014-04-18   19:25:00         F9 v1.1   CCAFS LC-40
# 8              10  2014-07-14   15:15:00         F9 v1.1   CCAFS LC-40
# 9              11  2014-08-05    8:00:00         F9 v1.1   CCAFS LC-40
# 10             12  2014-09-07    5:00:00   F9 v1.1 B1011   CCAFS LC-40
# 11             13  2014-09-21    5:52:00   F9 v1.1 B1010   CCAFS LC-40
# ...

# %%
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)
nasa_coordinate1 = [28.562302, -80.577356]
site_map = folium.Map(location=nasa_coordinate1, zoom_start=10)
nasa_coordinate2 = [28.563197, -80.576820]
site_map = folium.Map(location=nasa_coordinate2, zoom_start=10)
nasa_coordinate3 = [28.573255, -80.646895]
site_map = folium.Map(location=nasa_coordinate3, zoom_start=10)
nasa_coordinate4 = [34.632834, -120.610745]
site_map = folium.Map(location=nasa_coordinate4, zoom_start=10)

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate1, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('Launch Site : CCAFS LC-40'))
marker = folium.map.Marker(
    nasa_coordinate1,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'CCAFS LC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate2, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('Launch Site : CCAFS SLC-40'))
marker = folium.map.Marker(
    nasa_coordinate2,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'CCAFS SLC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate3, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('Launch Site : KSC LC-39A'))
marker = folium.map.Marker(
    nasa_coordinate3,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate4, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('Launch Site : VAFB SLC-4E'))
marker = folium.map.Marker(
    nasa_coordinate4,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'VAFB SLC-4E',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
circle = folium.Circle(nasa_coordinate1, radius=1000, color='#1D8348', fill=True).add_child(folium.Popup('Launch Site : CCAFS LC-40'))
marker = folium.map.Marker(
    nasa_coordinate1,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#1D8348;"><b>%s</b></div>' % 'CCAFS LC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate2, radius=1000, color='#1D8348', fill=True).add_child(folium.Popup('Launch Site : CCAFS SLC-40'))
marker = folium.map.Marker(
    nasa_coordinate2,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#1D8348;"><b>%s</b></div>' % 'CCAFS SLC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate3, radius=1000, color='#1D8348', fill=True).add_child(folium.Popup('Launch Site : KSC LC-39A'))
marker = folium.map.Marker(
    nasa_coordinate3,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#1D8348;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate4, radius=1000, color='#1D8348', fill=True).add_child(folium.Popup('Launch Site : VAFB SLC-4E'))
marker = folium.map.Marker(
    nasa_coordinate4,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#1D8348;"><b>%s</b></div>' % 'VAFB SLC-4E',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
circle = folium.Circle(nasa_coordinate1, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : CCAFS LC-40'))
marker = folium.map.Marker(
    nasa_coordinate1,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'CCAFS LC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate2, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : CCAFS SLC-40'))
marker = folium.map.Marker(
    nasa_coordinate2,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'CCAFS SLC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate3, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : KSC LC-39A'))
marker = folium.map.Marker(
    nasa_coordinate3,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate4, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : VAFB SLC-4E'))
marker = folium.map.Marker(
    nasa_coordinate4,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'VAFB SLC-4E',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Coordinates are 15 points on the great circle from Boston to San Francisco.
#nasa_coordinate = [29.559684888503615, -95.0830971930759]
#site_map = folium.Map(location=nasa_coordinate, zoom_start=10)
#nasa_coordinate1 = [28.562302, -80.577356]
#site_map = folium.Map(location=nasa_coordinate1, zoom_start=10)
#nasa_coordinate2 = [28.563197, -80.576820]
#site_map = folium.Map(location=nasa_coordinate2, zoom_start=10)
#nasa_coordinate3 = [28.573255, -80.646895]
#site_map = folium.Map(location=nasa_coordinate3, zoom_start=10)
#nasa_coordinate4 = [34.632834, -120.610745]
#site_map = folium.Map(location=nasa_coordinate4, zoom_start=10)
circle = folium.Circle(nasa_coordinate1, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : CCAFS LC-40'))
marker = folium.map.Marker(
    nasa_coordinate1,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'CCAFS LC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate2, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : CCAFS SLC-40'))
marker = folium.map.Marker(
    nasa_coordinate2,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'CCAFS SLC-40',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate3, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : KSC LC-39A'))
marker = folium.map.Marker(
    nasa_coordinate3,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

circle = folium.Circle(nasa_coordinate4, radius=1000, color='#A93226', fill=True).add_child(folium.Popup('Launch Site : VAFB SLC-4E'))
marker = folium.map.Marker(
    nasa_coordinate4,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#A93226;"><b>%s</b></div>' % 'VAFB SLC-4E',
        )
    )

site_map.add_child(circle)
site_map.add_child(marker)

coordinates = [
    [28.562302, -80.577356],
    [28.563197, -80.576820],
    [28.573255, -80.646895]
   ]

# Create the map and add the line
m = folium.Map(location=[28.39, -80.65], zoom_start=4)

folium.PolyLine(
    locations=coordinates,
    color="#FF0000",
    weight=5,
    tooltip="From Coast to Launch Site",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %%
marker_cluster = MarkerCluster()

# %%
circle = folium.Circle(nasa_coordinate3, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('Launch Site : KSC LC-39A'))
marker = folium.map.Marker(
    nasa_coordinate3,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    # marker = folium.Marker(...)
    marker_cluster.add_child(marker)

site_map
